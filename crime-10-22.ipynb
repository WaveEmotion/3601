# %% [markdown]
# ## read in data

# %%
import pandas as pd

# %%
crime_df = pd.read_csv("/Users/fabiolarojas/Documents/data-science/dtsc3601-2/project-3601/crimedata2.csv", encoding='ISO-8859-1')
crime_df.head()
# Out:
#             Êcommunityname state countyCode communityCode  fold  population  \
# 0  BerkeleyHeightstownship    NJ         39          5320     1       11980
# 1           Marpletownship    PA         45         47616     1       23123
# 2               Tigardcity    OR          ?             ?     1       29344
# 3         Gloversvillecity    NY         35         29443     1       16656
# 4              Bemidjicity    MN          7          5068     1       11245
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  burglaries  \
# 0           3.10          1.37         91.78          6.50  ...          14
# 1           2.82          0.80         95.57          3.44  ...          57
# 2           2.43          0.74         94.33          3.43  ...         274
# 3           2.40          1.70         97.35          0.50  ...         225
# 4           2.76          0.53         89.16          1.17  ...          91
#
# ...

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Columns: 147 entries, Êcommunityname to nonViolPerPop
# dtypes: float64(75), int64(29), object(43)
# memory usage: 2.5+ MB

# %%
crime_df.describe()
# Out:
#               fold    population  householdsize  racepctblack  racePctWhite  \
# count  2215.000000  2.215000e+03    2215.000000   2215.000000   2215.000000
# mean      5.494357  5.311798e+04       2.707327      9.335102     83.979819
# std       2.872924  2.046203e+05       0.334120     14.247156     16.419080
# min       1.000000  1.000500e+04       1.600000      0.000000      2.680000
# 25%       3.000000  1.436600e+04       2.500000      0.860000     76.320000
# 50%       5.000000  2.279200e+04       2.660000      2.870000     90.350000
# 75%       8.000000  4.302400e+04       2.850000     11.145000     96.225000
# max      10.000000  7.322564e+06       5.280000     96.670000     99.630000
#
#        racePctAsian  racePctHisp  agePct12t21  agePct12t29  agePct16t24  ...  \
# count   2215.000000  2215.000000  2215.000000  2215.000000  2215.000000  ...
# mean       2.670203     7.950176    14.445837    27.644840    13.975142  ...
# ...

# %% [markdown]
# ## filter columns

# %%
attributes = ['population', 
              'PopDens', 
              'numbUrban', 
              'pctUrban', 
              'medIncome', 
              'MedRent', 
              'PctHousOccup', 
              'PctHousOwnOcc', 
              'PersPerOwnOccHous', 
              'PersPerRentOccHous'
              ]
filtered_crime_df = crime_df[attributes]
filtered_crime_df
# Out:
#       population  PopDens  numbUrban  pctUrban  medIncome  MedRent  \
# 0          11980   1845.9      11980    100.00      75122     1001
# 1          23123   2186.7      23123    100.00      47917      627
# 2          29344   2780.9      29344    100.00      35669      484
# 3          16656   3217.7          0      0.00      20580      333
# 4          11245    974.2          0      0.00      17390      332
# ...          ...      ...        ...       ...        ...      ...
# 2210       56216   3365.4      56216    100.00      24727      438
# 2211       12251   1682.8      12251    100.00      20321      330
# 2212       32824   1195.2      32824    100.00      27182      514
# 2213       13547   2142.2          0      0.00      19899      316
# 2214       28898   1331.0      28664     99.19      23287      426
#
#       PctHousOccup  PctHousOwnOcc  PersPerOwnOccHous  PersPerRentOccHous
# 0            98.37          91.01               3.00                2.84
# ...

# %%
filtered_crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   population          2215 non-null   int64
#  1   PopDens             2215 non-null   float64
#  2   numbUrban           2215 non-null   int64
#  3   pctUrban            2215 non-null   float64
#  4   medIncome           2215 non-null   int64
#  5   MedRent             2215 non-null   int64
#  6   PctHousOccup        2215 non-null   float64
#  7   PctHousOwnOcc       2215 non-null   float64
#  8   PersPerOwnOccHous   2215 non-null   float64
#  9   PersPerRentOccHous  2215 non-null   float64
# dtypes: float64(6), int64(4)
# memory usage: 173.2 KB

# %%
filtered_crime_df[filtered_crime_df == "?"].any(axis=1).sum()
# Out:
# 0

# %%
filtered_crime_df.to_csv('filtered_crime_df.csv', index=False)

# %% [markdown]
# ## baseline
